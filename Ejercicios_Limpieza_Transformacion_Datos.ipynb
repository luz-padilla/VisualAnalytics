# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Ejercicio-Fechas-Publicación" data-toc-modified-id="Ejercicio-Fechas-Publicación-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Ejercicio Fechas Publicación</a></span></li><li><span><a href="#Ejercicio-Tipo-de-Contrato-y-Subtipo-de-Contrato" data-toc-modified-id="Ejercicio-Tipo-de-Contrato-y-Subtipo-de-Contrato-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ejercicio Tipo de Contrato y Subtipo de Contrato</a></span></li><li><span><a href="#Ejercicio-Duración-del-contrato" data-toc-modified-id="Ejercicio-Duración-del-contrato-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ejercicio Duración del contrato</a></span></li></ul></div>

# %% [markdown]
# # Ejercicios Limpieza de Datos <a class="tocSkip">
#
# por Mónica Tatiana Gutierrez B
#
# version 0.1, Feb 2021
#
# Parte de la clase Curso de visualización para ciencia de datos en Python

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) #Mostrar todas las columnas
from datetime import datetime, timedelta

# %%
df_SECOP = pd.read_csv('Datos_SECOP.csv', 
                 sep = ',',
                 index_col=0,
                 dtype={
                     'Nit Entidad': str
                 })
# Out:
#                                              Entidad Nit Entidad  \
# 0  SUPERINTENDENCIA DE VIGILANCIA Y SEGURIDAD PRI...   800217123
# 1  MUNICIPIO DE SANTIAGO DE CALI - SECRETARIA DE ...   890399011
# 2  SECRETARÍA GENERAL DE LA ALCALDÍA MAYOR DE BOGOTÁ   899999061
# 3  SENA REGIONAL DISTRITO CAPITAL Grupo Administr...   899999034
# 4  SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E...   900971006
#
#          Departamento Entidad Ciudad Entidad OrdenEntidad   ID del Proceso  \
# 0  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1090917
# 1                 No Definido    No Definido  Territorial  CO1.REQ.1263855
# 2                 No Definido    No Definido  Territorial  CO1.REQ.1116938
# 3  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1546629
# 4                 No Definido    No Definido  Territorial  CO1.REQ.1765407
#
#     Referencia del Proceso ID del Portafolio  \
# 0          CDPS-018-2020_2  CO1.BDOS.1054442
# 1  4145.010.32.1.0131-2020  CO1.BDOS.1225749
# 2        SGA-CD-151-2020_2  CO1.BDOS.1077727
# 3     PSP-DC-CICG-083-2020  CO1.BDOS.1501825
# 4            CPS-1339-2021  CO1.BDOS.1715307
#
#                             Nombre del Procedimiento                    Fase  \
# 0               CONTRATO DE PRESTACIÓN DE SERVICIOS.  Presentación de oferta
# 1  PROFESIONALES DESARROLLO DE ESTRATEGIAS PARA L...  Presentación de oferta
# 2                                  SGA-CD-151-2020_2  Presentación de oferta
# 3  Prestación de servicios personales de carácter...  Presentación de oferta
# 4  PRESTAR SERVICIOS PROFESIONALES Y APOYO A LA G...  Presentación de oferta
#
#   Fecha de Publicacion del Proceso Fecha de Ultima Publicación  Precio Base  \
# 0                       2020-01-21                  01/21/2020     34387200
# 1                       2020-04-29                  04/29/2020     29117793
# 2                       2020-02-03                  02/03/2020     29816133
# 3                       2020-10-15                  10/15/2020      6443255
# 4                       2021-01-29                  01/29/2021      2980278
#
#        Modalidad de Contratacion  Duracion Unidad de Duracion Adjudicado  \
# 0           Contratación directa         8              Meses         No
# 1           Contratación directa         0                 ND         No
# 2           Contratación directa       165               Dias         No
# 3           Contratación directa        51               Dias         No
# 4  Contratación régimen especial         1              Meses         No
#
#   ID Adjudicacion CodigoProveedor Nombre del Proveedor Adjudicado  \
# 0   No Adjudicado   No Adjudicado                   No Adjudicado
# 1   No Adjudicado   No Adjudicado                   No Adjudicado
# 2   No Adjudicado   No Adjudicado                   No Adjudicado
# 3   No Adjudicado   No Adjudicado                   No Adjudicado
# 4   No Adjudicado   No Adjudicado                   No Adjudicado
#
#   NIT del Proveedor Adjudicado Departamento Proveedor Ciudad Proveedor  \
# 0                No Adjudicado              No aplica        No aplica
# 1                No Adjudicado              No aplica        No aplica
# 2                No Adjudicado              No aplica        No aplica
# 3                No Adjudicado              No aplica        No aplica
# 4                No Adjudicado              No aplica        No aplica
#
#    Valor Total Adjudicacion                Tipo de Contrato  \
# 0                         0  Servicios de aprovisionamiento
# 1                         0  Servicios de aprovisionamiento
# 2                         0  Servicios de aprovisionamiento
# 3                         0  Servicios de aprovisionamiento
# 4                         0             Decreto 092 de 2017
#
#   Subtipo de Contrato
# 0     No Especificado
# 1     No Especificado
# 2     No Especificado
# 3     No Especificado
# 4     No Especificado

# %%
df_SECOP
# Out:
#                                                   Entidad Nit Entidad  \
# 0       SUPERINTENDENCIA DE VIGILANCIA Y SEGURIDAD PRI...   800217123
# 1       MUNICIPIO DE SANTIAGO DE CALI - SECRETARIA DE ...   890399011
# 2       SECRETARÍA GENERAL DE LA ALCALDÍA MAYOR DE BOGOTÁ   899999061
# 3       SENA REGIONAL DISTRITO CAPITAL Grupo Administr...   899999034
# 4       SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E...   900971006
# ...                                                   ...         ...
# 805626                            MINISTERIO DEL INTERIOR   830114475
# 805627  SECRETARIA DE INFRAESTRUCTURA Y VALORIZACION -...  8903990295
# 805628                           HOSPITAL MILITAR CENTRAL   830040256
# 805629  HOSPITAL FEDERICO LLERAS ACOSTA DE IBAGUE TOLI...   890706833
# 805630               UNIDAD PRESTADORA DE SALUD SANTANDER   901361090
#
#               Departamento Entidad Ciudad Entidad OrdenEntidad  \
# 0       Distrito Capital de Bogotá         Bogotá     Nacional
# 1                      No Definido    No Definido  Territorial
# 2                      No Definido    No Definido  Territorial
# 3       Distrito Capital de Bogotá         Bogotá     Nacional
# 4                      No Definido    No Definido  Territorial
# ...                            ...            ...          ...
# 805626                 No Definido    No Definido     Nacional
# 805627             Valle del Cauca           Cali  Territorial
# 805628  Distrito Capital de Bogotá    No Definido     Nacional
# 805629                      Tolima         Ibagué  Territorial
# 805630                   Santander    Bucaramanga     Nacional
#
#          ID del Proceso                  Referencia del Proceso  \
# 0       CO1.REQ.1090917                         CDPS-018-2020_2
# 1       CO1.REQ.1263855                 4145.010.32.1.0131-2020
# 2       CO1.REQ.1116938                       SGA-CD-151-2020_2
# 3       CO1.REQ.1546629                    PSP-DC-CICG-083-2020
# 4       CO1.REQ.1765407                           CPS-1339-2021
# ...                 ...                                     ...
# 805626   CO1.REQ.650468                         PS 2016 DE 2018
# 805627  CO1.REQ.1717088                      1.310.02-59.2-0158
# 805628   CO1.REQ.643808                             CD 104-2018
# 805629  CO1.REQ.1711499  OAJ-2021-0108-MAYRA ALEJANDRA QUINTERO
# 805630  CO1.REQ.1189906             PN UPRES DESAN MIC 041 2020
#
#        ID del Portafolio                           Nombre del Procedimiento  \
# 0       CO1.BDOS.1054442               CONTRATO DE PRESTACIÓN DE SERVICIOS.
# 1       CO1.BDOS.1225749  PROFESIONALES DESARROLLO DE ESTRATEGIAS PARA L...
# 2       CO1.BDOS.1077727                                  SGA-CD-151-2020_2
# 3       CO1.BDOS.1501825  Prestación de servicios personales de carácter...
# 4       CO1.BDOS.1715307  PRESTAR SERVICIOS PROFESIONALES Y APOYO A LA G...
# ...                  ...                                                ...
# 805626   CO1.BDOS.629401                    VIVIANA MARCELA SOLANO RESTREPO
# 805627  CO1.BDOS.1666344                                 1.310.02-59.2-0158
# 805628   CO1.BDOS.622411                        MEDICO GENERAL DE URGENCIAS
# 805629  CO1.BDOS.1660998             OAJ-2021-0108-MAYRA ALEJANDRA QUINTERO
# 805630  CO1.BDOS.1151882  PRESTACION DE SERVICIOS PROFESIONALES COMO TER...
#
#                           Fase Fecha de Publicacion del Proceso  \
# 0       Presentación de oferta                       2020-01-21
# 1       Presentación de oferta                       2020-04-29
# 2       Presentación de oferta                       2020-02-03
# 3       Presentación de oferta                       2020-10-15
# 4       Presentación de oferta                       2021-01-29
# ...                        ...                              ...
# 805626  Presentación de oferta                       2018-12-10
# 805627  Presentación de oferta                       2021-01-17
# 805628  Presentación de oferta                       2018-12-06
# 805629  Presentación de oferta                       2021-01-20
# 805630         Fase de ofertas                       2020-03-06
#
#        Fecha de Ultima Publicación  Precio Base  \
# 0                       2020-01-21     34387200
# 1                       2020-04-29     29117793
# 2                       2020-02-03     29816133
# 3                       2020-10-15      6443255
# 4                       2021-01-29      2980278
# ...                            ...          ...
# 805626                  2018-12-10      2700000
# 805627                  2021-01-17     21000000
# 805628                  2018-12-06     56982410
# 805629                  2021-01-20     31533450
# 805630                  2020-03-06      7846437
#
#             Modalidad de Contratacion  Duracion Unidad de Duracion Adjudicado  \
# 0                Contratación directa         8              Meses         No
# 1                Contratación directa         0                 ND         No
# 2                Contratación directa       165               Dias         No
# 3                Contratación directa        51               Dias         No
# 4       Contratación régimen especial         1              Meses         No
# ...                               ...       ...                ...        ...
# 805626           Contratación directa        21               Dias         No
# 805627           Contratación directa        90               Dias         No
# 805628           Contratación directa        12              Meses         No
# 805629  Contratación régimen especial         5              Meses         No
# 805630           Contratación directa       125               Dias         No
#
#        ID Adjudicacion CodigoProveedor Nombre del Proveedor Adjudicado  \
# 0        No Adjudicado   No Adjudicado                   No Adjudicado
# 1        No Adjudicado   No Adjudicado                   No Adjudicado
# 2        No Adjudicado   No Adjudicado                   No Adjudicado
# 3        No Adjudicado   No Adjudicado                   No Adjudicado
# 4        No Adjudicado   No Adjudicado                   No Adjudicado
# ...                ...             ...                             ...
# 805626   No Adjudicado   No Adjudicado                   No Adjudicado
# 805627   No Adjudicado   No Adjudicado                   No Adjudicado
# 805628   No Adjudicado   No Adjudicado                   No Adjudicado
# 805629   No Adjudicado   No Adjudicado                   No Adjudicado
# 805630   No Adjudicado   No Adjudicado                   No Adjudicado
#
#        NIT del Proveedor Adjudicado Departamento Proveedor Ciudad Proveedor  \
# 0                     No Adjudicado              No aplica        No aplica
# 1                     No Adjudicado              No aplica        No aplica
# 2                     No Adjudicado              No aplica        No aplica
# 3                     No Adjudicado              No aplica        No aplica
# 4                     No Adjudicado              No aplica        No aplica
# ...                             ...                    ...              ...
# 805626                No Adjudicado              No aplica        No aplica
# 805627                No Adjudicado              No aplica        No aplica
# 805628                No Adjudicado              No aplica        No aplica
# 805629                No Adjudicado              No aplica        No aplica
# 805630                No Adjudicado              No aplica        No aplica
#
#         Valor Total Adjudicacion                Tipo de Contrato  \
# 0                              0  Servicios de aprovisionamiento
# 1                              0  Servicios de aprovisionamiento
# 2                              0  Servicios de aprovisionamiento
# 3                              0  Servicios de aprovisionamiento
# 4                              0             Decreto 092 de 2017
# ...                          ...                             ...
# 805626                         0  Servicios de aprovisionamiento
# 805627                         0  Servicios de aprovisionamiento
# 805628                         0  Servicios de aprovisionamiento
# 805629                         0  Servicios de aprovisionamiento
# 805630                         0  Servicios de aprovisionamiento
#
#        Subtipo de Contrato Dif_fechas
# 0          No Especificado     0 days
# 1          No Especificado     0 days
# 2          No Especificado     0 days
# 3          No Especificado     0 days
# 4          No Especificado     0 days
# ...                    ...        ...
# 805626     No Especificado     0 days
# 805627     No Especificado     0 days
# 805628     No Especificado     0 days
# 805629     No Especificado     0 days
# 805630     No Especificado     0 days
#
# [781762 rows x 27 columns]

# %% [markdown]
# ## Ejercicio Fechas Publicación

# %% [markdown]
# Teniendo en cuenta que existe una Fecha de Publicación del Proceso y una fecha de última publicación, realice la limpieza de formato de dichas variables. Defina una nueva variable en la que se calcule la diferencia de éstas dos fechas y responda si incluiría las dos fechas dentro de la fuente de datos.
#
# *Utilice estadísticas descriptivas para responder la pregunta*

# %%
df_SECOP['Fecha de Publicacion del Proceso'] = pd.to_datetime(df_SECOP['Fecha de Publicacion del Proceso'],format='%Y/%m/%d')
df_SECOP['Fecha de Ultima Publicación'] = pd.to_datetime(df_SECOP['Fecha de Ultima Publicación'],format='%m/%d/%Y')
df_SECOP['Fecha de Publicacion del Proceso'].head()
# Out:
# 0   2020-01-21
# 1   2020-04-29
# 2   2020-02-03
# 3   2020-10-15
# 4   2021-01-29
# Name: Fecha de Publicacion del Proceso, dtype: datetime64[ns]

# %%
df_SECOP['Dif_fechas']= df_SECOP['Fecha de Publicacion del Proceso']- df_SECOP['Fecha de Ultima Publicación']
df_SECOP.head()
# Out:
#                                              Entidad Nit Entidad  \
# 0  SUPERINTENDENCIA DE VIGILANCIA Y SEGURIDAD PRI...   800217123
# 1  MUNICIPIO DE SANTIAGO DE CALI - SECRETARIA DE ...   890399011
# 2  SECRETARÍA GENERAL DE LA ALCALDÍA MAYOR DE BOGOTÁ   899999061
# 3  SENA REGIONAL DISTRITO CAPITAL Grupo Administr...   899999034
# 4  SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E...   900971006
#
#          Departamento Entidad Ciudad Entidad OrdenEntidad   ID del Proceso  \
# 0  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1090917
# 1                 No Definido    No Definido  Territorial  CO1.REQ.1263855
# 2                 No Definido    No Definido  Territorial  CO1.REQ.1116938
# 3  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1546629
# 4                 No Definido    No Definido  Territorial  CO1.REQ.1765407
#
#     Referencia del Proceso ID del Portafolio  \
# 0          CDPS-018-2020_2  CO1.BDOS.1054442
# 1  4145.010.32.1.0131-2020  CO1.BDOS.1225749
# 2        SGA-CD-151-2020_2  CO1.BDOS.1077727
# 3     PSP-DC-CICG-083-2020  CO1.BDOS.1501825
# 4            CPS-1339-2021  CO1.BDOS.1715307
#
#                             Nombre del Procedimiento                    Fase  \
# 0               CONTRATO DE PRESTACIÓN DE SERVICIOS.  Presentación de oferta
# 1  PROFESIONALES DESARROLLO DE ESTRATEGIAS PARA L...  Presentación de oferta
# 2                                  SGA-CD-151-2020_2  Presentación de oferta
# 3  Prestación de servicios personales de carácter...  Presentación de oferta
# 4  PRESTAR SERVICIOS PROFESIONALES Y APOYO A LA G...  Presentación de oferta
#
#   Fecha de Publicacion del Proceso Fecha de Ultima Publicación  Precio Base  \
# 0                       2020-01-21                  2020-01-21     34387200
# 1                       2020-04-29                  2020-04-29     29117793
# 2                       2020-02-03                  2020-02-03     29816133
# 3                       2020-10-15                  2020-10-15      6443255
# 4                       2021-01-29                  2021-01-29      2980278
#
#        Modalidad de Contratacion  Duracion Unidad de Duracion Adjudicado  \
# 0           Contratación directa         8              Meses         No
# 1           Contratación directa         0                 ND         No
# 2           Contratación directa       165               Dias         No
# 3           Contratación directa        51               Dias         No
# 4  Contratación régimen especial         1              Meses         No
#
#   ID Adjudicacion CodigoProveedor Nombre del Proveedor Adjudicado  \
# 0   No Adjudicado   No Adjudicado                   No Adjudicado
# 1   No Adjudicado   No Adjudicado                   No Adjudicado
# 2   No Adjudicado   No Adjudicado                   No Adjudicado
# 3   No Adjudicado   No Adjudicado                   No Adjudicado
# 4   No Adjudicado   No Adjudicado                   No Adjudicado
#
#   NIT del Proveedor Adjudicado Departamento Proveedor Ciudad Proveedor  \
# 0                No Adjudicado              No aplica        No aplica
# 1                No Adjudicado              No aplica        No aplica
# 2                No Adjudicado              No aplica        No aplica
# 3                No Adjudicado              No aplica        No aplica
# 4                No Adjudicado              No aplica        No aplica
#
#    Valor Total Adjudicacion                Tipo de Contrato  \
# 0                         0  Servicios de aprovisionamiento
# 1                         0  Servicios de aprovisionamiento
# 2                         0  Servicios de aprovisionamiento
# 3                         0  Servicios de aprovisionamiento
# 4                         0             Decreto 092 de 2017
#
#   Subtipo de Contrato Dif_fechas
# 0     No Especificado     0 days
# 1     No Especificado     0 days
# 2     No Especificado     0 days
# 3     No Especificado     0 days
# 4     No Especificado     0 days

# %%
df_SECOP['Dif_fechas'].describe()
# Out:
# count                       781762
# mean     0 days 03:29:33.590427777
# std      0 days 08:27:47.428905545
# min                0 days 00:00:00
# 25%                0 days 00:00:00
# 50%                0 days 00:00:00
# 75%                0 days 00:00:00
# max                1 days 00:00:00
# Name: Dif_fechas, dtype: object

# %% [markdown]
#  Respuesta: no solo inlcuiria una de las fechas

# %% [markdown]
# ## Ejercicio Tipo de Contrato y Subtipo de Contrato
# De acuerdo con las variables Contrato y Subcontrato, realice una tabla cruzada y responda ¿Vale la pena dejar ambas variables en la fuente de datos?

# %%
pd.crosstab(index=df_SECOP['Tipo de Contrato'], columns=df_SECOP['Subtipo de Contrato'],
            margins=True)
# Out:
# Subtipo de Contrato             No Especificado     All
# Tipo de Contrato
# 27 - Otros servicios                      40200   40200
# Acuerdo Marco                               962     962
# Alquiler de edificios                      7156    7156
# Arrendamiento Muebles                       505     505
# Comisión                                     82      82
# Compraventa                               41921   41921
# Concesión                                   104     104
# Consultoría                                4110    4110
# Decreto 092 de 2017                       26740   26740
# Interventoría                              4678    4678
# ND                                         5068    5068
# No Especificado                               4       4
# Obra                                      11648   11648
# Seguros                                    2142    2142
# Servicios de aprovisionamiento           591304  591304
# Suministros                               45029   45029
# Ventas de muebles                           109     109
# All                                      781762  781762

# %% [markdown]
# Respuesta: No vale la pena, ambas variables contienen la misma información

# %% [markdown]
# ## Ejercicio Duración del contrato
# Teniendo en cuenta que la duración de los contratos tiene métricas diferentes, encuentre una estrategia para crear una nueva variable en la cuál se encuentre parametrizada la variable de duración del contrato.

# %%
df_SECOP['Unidad de Duracion'].value_counts()
# Out:
# Dias     390312
# Meses    358815
# ND        26337
# Años       6298
# Name: Unidad de Duracion, dtype: int64

# %%
df_SECOP[['Unidad de Duracion','Duracion']].sample(20)
# Out:
#        Unidad de Duracion  Duracion
# 65723               Meses         5
# 187533              Meses        11
# 803114              Meses         4
# 556552              Meses         6
# 347984              Meses         6
# 244723               Dias       345
# 38169                Dias       330
# 624114              Meses         4
# 371379              Meses         7
# 384426               Dias       145
# 25772                Dias       180
# 688710               Dias        60
# 547263               Dias        30
# 111272               Dias       300
# 293092               Dias       359
# 467719                 ND         0
# 421116              Meses         2
# 680976              Meses         3
# 313880               Dias       347
# 716156               Dias        30

# %%
Unidad de duraci

# %% [markdown]
# Se parametriza a numero de dias de una nueva variable llamada duracion_param

# %%
df_SECOP2= df_SECOP.rename(columns={'Unidad de Duracion':'Unidad_de_Duracion'})

# %%
duracion_param =[]
for i in df_SECOP2.index:
    if df_SECOP2.Unidad_de_Duracion[i] == 'Meses':
        duracion_param.append(int(df_SECOP2.Duracion[i])*30)
    elif df_SECOP2.Unidad_de_Duracion[i] == 'Años':
        duracion_param.append(df_SECOP2.Duracion[i]*365)
    elif df_SECOP2.Unidad_de_Duracion[i] == 'Dias':
        duracion_param.append(df_SECOP2.Duracion[i])
    else :
        duracion_param.append(df_SECOP2.Duracion[i])

# %%
df_SECOP['duracion_param']= duracion_param

# %%
df_SECOP.head()
# Out:
#                                              Entidad Nit Entidad  \
# 0  SUPERINTENDENCIA DE VIGILANCIA Y SEGURIDAD PRI...   800217123
# 1  MUNICIPIO DE SANTIAGO DE CALI - SECRETARIA DE ...   890399011
# 2  SECRETARÍA GENERAL DE LA ALCALDÍA MAYOR DE BOGOTÁ   899999061
# 3  SENA REGIONAL DISTRITO CAPITAL Grupo Administr...   899999034
# 4  SUBRED INTEGRADA DE SERVICIOS DE SALUD NORTE E...   900971006
#
#          Departamento Entidad Ciudad Entidad OrdenEntidad   ID del Proceso  \
# 0  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1090917
# 1                 No Definido    No Definido  Territorial  CO1.REQ.1263855
# 2                 No Definido    No Definido  Territorial  CO1.REQ.1116938
# 3  Distrito Capital de Bogotá         Bogotá     Nacional  CO1.REQ.1546629
# 4                 No Definido    No Definido  Territorial  CO1.REQ.1765407
#
#     Referencia del Proceso ID del Portafolio  \
# 0          CDPS-018-2020_2  CO1.BDOS.1054442
# 1  4145.010.32.1.0131-2020  CO1.BDOS.1225749
# 2        SGA-CD-151-2020_2  CO1.BDOS.1077727
# 3     PSP-DC-CICG-083-2020  CO1.BDOS.1501825
# 4            CPS-1339-2021  CO1.BDOS.1715307
#
#                             Nombre del Procedimiento                    Fase  \
# 0               CONTRATO DE PRESTACIÓN DE SERVICIOS.  Presentación de oferta
# 1  PROFESIONALES DESARROLLO DE ESTRATEGIAS PARA L...  Presentación de oferta
# 2                                  SGA-CD-151-2020_2  Presentación de oferta
# 3  Prestación de servicios personales de carácter...  Presentación de oferta
# 4  PRESTAR SERVICIOS PROFESIONALES Y APOYO A LA G...  Presentación de oferta
#
#   Fecha de Publicacion del Proceso Fecha de Ultima Publicación  Precio Base  \
# 0                       2020-01-21                  2020-01-21     34387200
# 1                       2020-04-29                  2020-04-29     29117793
# 2                       2020-02-03                  2020-02-03     29816133
# 3                       2020-10-15                  2020-10-15      6443255
# 4                       2021-01-29                  2021-01-29      2980278
#
#        Modalidad de Contratacion  Duracion Unidad de Duracion Adjudicado  \
# 0           Contratación directa         8              Meses         No
# 1           Contratación directa         0                 ND         No
# 2           Contratación directa       165               Dias         No
# 3           Contratación directa        51               Dias         No
# 4  Contratación régimen especial         1              Meses         No
#
#   ID Adjudicacion CodigoProveedor Nombre del Proveedor Adjudicado  \
# 0   No Adjudicado   No Adjudicado                   No Adjudicado
# 1   No Adjudicado   No Adjudicado                   No Adjudicado
# 2   No Adjudicado   No Adjudicado                   No Adjudicado
# 3   No Adjudicado   No Adjudicado                   No Adjudicado
# 4   No Adjudicado   No Adjudicado                   No Adjudicado
#
#   NIT del Proveedor Adjudicado Departamento Proveedor Ciudad Proveedor  \
# 0                No Adjudicado              No aplica        No aplica
# 1                No Adjudicado              No aplica        No aplica
# 2                No Adjudicado              No aplica        No aplica
# 3                No Adjudicado              No aplica        No aplica
# 4                No Adjudicado              No aplica        No aplica
#
#    Valor Total Adjudicacion                Tipo de Contrato  \
# 0                         0  Servicios de aprovisionamiento
# 1                         0  Servicios de aprovisionamiento
# 2                         0  Servicios de aprovisionamiento
# 3                         0  Servicios de aprovisionamiento
# 4                         0             Decreto 092 de 2017
#
#   Subtipo de Contrato Dif_fechas  duracion_param
# 0     No Especificado     0 days               8
# 1     No Especificado     0 days               0
# 2     No Especificado     0 days             165
# 3     No Especificado     0 days              51
# 4     No Especificado     0 days               1

# %% [markdown]
# # Taller 1
#
# **Autor: Luz Adriana Rodriguez Padilla**
#
# **Fecha: 25/02/2021**

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://s3.amazonaws.com/infobeautiful-bnews/images/1040/1040-soy-oat-milk.svg", width=500)
# Out:
# <img src="https://s3.amazonaws.com/infobeautiful-bnews/images/1040/1040-soy-oat-milk.svg" width="500"/>

# %% [markdown]
# # Framework de visualización

# %% [markdown]
# ##  1. ¿Que? (Abstracción de los datos)

# %% [markdown]
# * Tipo de Dataset: Tabla
#
# * Tipos de datos:
#
#  - items
#
#  - Atrubutos cuantitativos
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##  2. ¿Por qué? (Abstracción de las tareas)

# %% [markdown]
# **1. Actions**
#
# * Analizar:
#
#  - Consumir: Presentar o explicar
#
#  - Producir: Derivar
#
# * Especificas:
#
#  - Buscar: lookup
#  - Consulta: comparar
#
#
# **2. Objetivos**
#
# * Atributos: Similar

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="500"/>
# </div>

# %% [markdown]
# ##  3. ¿Cómo? (Selección del modismo)

# %% [markdown]
# 1. Encode
#
#  * Arreglar: separado
#
#  * Map: Color (matiz)

# %% [markdown]
# # Marcas y Canales

# %% [markdown]
# 1. Marca
#
#  * Marca de linea
#
# 2. Canal
#
#  * posición: Canal de posición espacial horizontal para el atributo cuantitativo y vertical para el atributo categorico
#
#  * Tamaño : largo de la marca
#
#  * Color: Canal de color para cada atributo cuantitativo.

# %% [markdown]
# Efectivamente esta visualización cumple con las reglas generales, pues aunque esta es sencilla y sin modismos de interacción, es eficiente, pues es una visualización de facil entendimiento y provee al espectador de la información en un diseño amable y agradable de ver.
#
# Las marcas y canales de esta visualización estan bien pensados, realmente no hay algo que tenga que agregarle o quitarle, ya que la vis es concisa y aporta toda la información necesaria de la huella ambiental que deja la producción en cada tipo de leche.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Framework de visualización

# %% [markdown]
# ##  1. ¿Que? (Abstracción de los datos)

# %% [markdown]
# * Tipo de Dataset:
#
#  - Geometrico
#
#  - Disponibilidad de datos
#
# * Tipos de datos:
#
#  - items
#
#  - Atributos cuatitativos
#
#  - Posición
#
#  - Dinamicos
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ##  2. ¿Por qué? (Abstracción de las tareas)

# %% [markdown]
# **1. Actions**
#
# * Analizar:
#
#  - Consumir: Presentar
#  - Producir: Registrar
#
# * Especificas:
#
#  - Buscar: Navegar
#  - Consulta: Resumir
#
#
# **2. Objetivos**
#
# * Datos espaciales
#
#  - Forma

# %% [markdown]
# ##  3. ¿Cómo? (Selección del modismo)

# %% [markdown]
# 1. Encode
#
#  * Organizar: Uso
#
#  * Map:
#
#     - Color: Luminancia
#
#
#
# 2. Manipulación
#
#  * Cambiar
#  * Seleccionar
#  * Navegar
#
# 3. Reducir
#
#  * Filtrar

# %% [markdown]
# # Marcas y Canales

# %% [markdown]
# 1. Marca
#
#  * Marca de area
#
# 2. Canal
#
#  * posición: Canal de posición espacial vertical y horizontal
#
#  * Tamaño : Canal del tamaño de Area
#
#  * Color: Canal de color para cada area

# %% [markdown]
# Esta visualización cumple con la regla general de tener en cuenta primero la visión general, zoom y filtros, en esta podemos ver mas la interacción entre la reducción de datos en general y la navegación, pues a la visulización podemos filtrarla por nivel de desagregación y luego ver a detalle el total o el porcetaje de personas que consumen drogas ya sea por red, por localidad o por UPZ, esta información se mostrara tanto en la visualización del mapa como en una tabla que hace de apoyo a la visualización.
#
# En cuanto a la regla general de capacidad de respuesta, la constante de tiempo de respuesta inmediata es mas de un segundo, ademas acciones como actulizaciones de pantallas pueden tardar mas de 5 segundos, por lo tanto la visulaización carece en el cumplimiento de esta regla general.

# %% [markdown]
# En cuanto a las marcas, pensaria que hubiera sido bueno agregar una marca de puntos los cuales representarian cada uno una droga estos estarian sobrepuestos en la marca de area, con lo cual ademas de decirnos la ubicación geografica y total de personas que consumen, nos dijera también que drogas son las mas utilizadas, esto atravez del canal de tamaño de area de los puntos, asi entre mas grande sea un punto mas consumo de la droga representada.

# %% [markdown]
# # Bibliografía
#
# 1. New York Times.Soy & Oat Milk are Most sustainable [imagen]. Recuperado de https://informationisbeautiful.net/beautifulnews/1040-soy-oat-milk/
#
# 2. Segovia, J. (2018).Comandos PostgreSQL [Imagen]. Recuperado de https://todopostgresql.com/wp-content/uploads/2018/08/curso5_facebook.png
#
# 3. Secretaría de Salud. (2020). Caracterización del consumo de sustancias psicoactivas en la población atendida por las UPGDS y UI en el Distrito Capital. Bogotá. https://dflemusp.shinyapps.io/VespApp/
